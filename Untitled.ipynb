# %%
import pandas as pd

# %%
file = pd.read_table("company_on_reddit",skiprows=1)

# %%
file.describe
# Out:
# <bound method NDFrame.describe of                                           .Club Domains    0  \
# 0                                              1010data    0
# 1                                            10X10 Room    0
# 2                                              121nexus    0
# 3                                                15Five    0
# 4                                           170 Systems    0
# 5                                       1Energy Systems    0
# 6                                           24PageBooks    0
# 7                                                 250ok    0
# 8                                              27 bards    0
# 9                                  2GO Mobile Solutions    0
# 10                             2nd Story Software, Inc.    0
# 11                                   30 Second Showcase    0
# 12                                3ClickEMR Corporation    0
# 13                                 3D Sports Technology    0
# ...
