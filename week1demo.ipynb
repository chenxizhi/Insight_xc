# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl

os.getcwd()
os.chdir('/Users/xintongchen/Downloads/crunchbase-october-2013')

# %%
rounds = pd.read_csv('crunchbase-rounds.csv',encoding='iso-8859-1')
company = pd.read_csv('crunchbase-companies.csv',encoding='iso-8859-1')
investment = pd.read_csv('crunchbase-investments.csv', encoding='iso-8859-1',low_memory=False)
acquisition = pd.read_csv('crunchbase-acquisitions.csv',encoding='iso-8859-1')

# %%
company[company.status=='closed']
# Out:
#                                           permalink  \
# 13                           /company/11i-solutions
# 36                             /company/24pagebooks
# 39                                /company/27-perry
# 52                   /company/3clickemr-corporation
# 143                           /company/abound-solar
# 168    /company/accelerated-orthopedic-technologies
# 172                              /company/accelgolf
# 297                             /company/ad-knights
# 298                              /company/ad-summos
# 313                           /company/adaptive-tcr
# 346                               /company/adexlink
# 540                             /company/aginfolink
# 613                                 /company/akimbo
# 721                            /company/alphanation
# 722                            /company/alphastripe
# 730                /company/alta-wind-energy-center
# 731                    /company/altair-therapeutics
# ...

# %%
investment['funding_round_type']=investment['funding_round_type'].apply(lambda x: str(x).split(','))

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
investment_vc = investment.funding_round_type.apply(tuple).value_counts()

# %%
investment_vc.dropna().plot(kind='barh')

# %%
investment.shape
# Out:
# (52870, 20)

# %%
investment2 = investment.applymap(str)
investment2.describe(include='all')
# Out:
#        company_permalink company_name company_category_code  \
# count              52870        52870                 52870
# unique             11574        11574                    44
# top      /company/ecomom       ecomom              software
# freq                  58           58                  7243
#
#        company_country_code company_state_code company_region   company_city  \
# count                 52870              52870          52870          52870
# unique                    3                 51            547           1230
# top                     USA                 CA         SF Bay  San Francisco
# freq                  52868              27054          22167           8650
#
#                                        investor_permalink  \
# count                                               52870
# unique                                              10553
# top     /financial-organization/new-enterprise-associates
# ...

# %%
rounds2 = rounds.applymap(str)
rounds2.describe(include='all')
# Out:
#        company_permalink company_name company_category_code  \
# count              31679        31679                 31679
# unique             17622        17622                    43
# top       /company/aviir        Aviir              software
# freq                  14           14                  4574
#
#        company_country_code company_state_code company_region   company_city  \
# count                 31679              31679          31679          31679
# unique                    1                 52            790           1955
# top                     USA                 CA         SF Bay  San Francisco
# freq                  31679              12644           9489           3194
#
#        funding_round_type   funded_at funded_month funded_quarter funded_year  \
# count               31679       31679        31679          31679       31679
# unique                  9        2991          212             84          28
# ...
